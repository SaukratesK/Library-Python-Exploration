# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('survey_results_schema.csv', index_col='Column')

# %%
df.loc[150:173, 'Hobbyist':'Country']
# Out:
#            Hobbyist   Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# Respondent
# 150             Yes   NaN         12   Yearly   300000.0       300000.0
# 151             Yes  35.0         10  Monthly    20000.0         9792.0
# 152             Yes  30.0         16  Monthly    10000.0       121980.0
# 153              No  30.0         16   Yearly    90000.0        90000.0
# 154              No  42.0         12   Yearly   150000.0       150000.0
# 155             Yes  43.0         10   Yearly    80000.0        80000.0
# 156             Yes  25.0         16   Yearly   125000.0       125000.0
# 157              No  26.0         15   Yearly    85000.0        64287.0
# 158             Yes  40.0         18   Yearly   170000.0       170000.0
# 159             Yes   NaN         12   Yearly   112000.0       112000.0
# 160             Yes  32.0          8   Yearly   141000.0       141000.0
# 161             Yes  24.0         14  Monthly     2800.0        36324.0
# ...

# %%
schema_df
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
schema_df.loc['Ethnicity':'JobSeek']
schema_df.sort_index(ascending=False)
# Out:
#                                                                    QuestionText
# Column
# YearsCodePro                  NOT including education, how many years have y...
# YearsCode                     Including any education, how many years have y...
# WorkWeekHrs                   On average, how many hours per week do you wor...
# WelcomeChange                 Compared to last year, how welcome do you feel...
# WebframeWorkedWith            Which web frameworks have you done extensive d...
# WebframeDesireNextYear        Which web frameworks have you done extensive d...
# UndergradMajor                            What was your primary field of study?
# Trans                                                      Are you transgender?
# SurveyLength                  How do you feel about the length of the survey...
# SurveyEase                    How easy or difficult was this survey to compl...
# Sexuality                     Which of the following describe you, if any? P...
# ...

# %%
df['Age'].value_counts()
# Out:
# 25.0     2693
# 28.0     2412
# 30.0     2406
# 26.0     2391
# 27.0     2338
# 24.0     2275
# 29.0     2219
# 23.0     2213
# 22.0     1884
# 32.0     1781
# 31.0     1716
# 21.0     1628
# 33.0     1527
# 35.0     1485
# 34.0     1374
# 20.0     1204
# 36.0     1129
# 38.0     1094
# 37.0     1057
# 40.0      914
# 39.0      858
# 19.0      816
# 18.0      644
# 42.0      626
# 41.0      591
# 43.0      520
# 45.0      472
# 17.0      422
# 44.0      397
# 46.0      348
# 48.0      341
# 16.0      326
# 49.0      306
# 47.0      298
# 50.0      292
# 15.0      231
# 51.0      211
# 52.0      205
# 55.0      185
# 53.0      172
# 54.0      161
# 56.0      124
# 57.0      118
# 14.0      111
# 58.0      102
# 59.0       94
# 60.0       88
# 63.0       76
# 61.0       67
# 13.0       63
# 62.0       60
# 64.0       43
# 66.0       43
# 65.0       36
# 67.0       25
# 12.0       23
# 69.0       23
# 70.0       19
# 72.0       18
# 68.0       18
# 71.0       15
# 73.0       14
# ...

# %%
pd.set_option("display.max_rows", 110)

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
people = {
    'first':['Corey','Jane','John'],
    'last':['Schafer','Doe','Doe'],
    'email':['CoreyMSchafer@gmail.com','JaneDoe@gmail.com','JohnDoe@gmail.com']
}

# %%
df_2 = pd.DataFrame(people)

# %%
df_2
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com

# %%
filt = (df_2['last'] == 'Doe') | (df_2['first'] == 'Jane')

# %%
df_2[filt]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@gmail.com
# 2  John  Doe  JohnDoe@gmail.com

# %%
df_2.loc[~filt, ['last','email']]
# Out:
#       last                    email
# 0  Schafer  CoreyMSchafer@gmail.com

# %%
filt2 = (df['Age'] > 30) & (df['Age'] < 32)

# %%
df[filt2]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 32                             I am a developer by profession      Yes  31.0
# 61                             I am a developer by profession      Yes  31.0
# 92                             I am a developer by profession      Yes  31.0
# 171                            I am a developer by profession      Yes  31.0
# ...                                                       ...      ...   ...
# 63082                          I am a developer by profession      Yes  31.0
# 63236                          I am a developer by profession       No  31.0
# 63288                          I am a developer by profession       No  31.0
# 14959                                                     NaN      Yes  31.0
# 30238                                                     NaN      Yes  31.0
#
# ...

# %%
high_salary = (df['ConvertedComp']>70000)

# %%
df.loc[high_salary, ['Country','Age','LanguageWorkedWith']]
# Out:
#                    Country   Age  \
# Respondent
# 8            United States  36.0
# 16          United Kingdom  45.0
# 17           United States  25.0
# 18           United States  32.0
# 19           United States  24.0
# ...                    ...   ...
# 65586        United States   NaN
# 65589        United States   NaN
# 65602        United States   NaN
# 65604        United States   NaN
# 65617              Germany   NaN
#
#                                            LanguageWorkedWith
# Respondent
# 8                                                  Python;SQL
# 16          Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 17                      C#;HTML/CSS;JavaScript;Python;SQL;VBA
# 18                        Bash/Shell/PowerShell;HTML/CSS;Perl
# 19          Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;S...
# ...                                                       ...
# 65586                                                     NaN
# ...

# %%
countries = ['United States', 'Germany']

# %%
filt3 = df['Country'].isin(countries)

# %%
df.loc[filt3, ['Age','Country']]
# Out:
#              Age        Country
# Respondent
# 1            NaN        Germany
# 5           31.0  United States
# 6            NaN        Germany
# 8           36.0  United States
# 14          27.0  United States
# ...          ...            ...
# 58498       32.0  United States
# 58896       29.0  United States
# 60931        NaN  United States
# 63077        NaN  United States
# 64858        NaN  United States
#
# [16359 rows x 2 columns]

# %%
filt4 = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filt4, 'LanguageWorkedWith']
# Out:
# Respondent
# 3                                 Objective-C;Python;Swift
# 8                                               Python;SQL
# 10                     HTML/CSS;Java;JavaScript;Python;SQL
# 13                                     C;JavaScript;Python
# 15        Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
#                                ...
# 61561    Bash/Shell/PowerShell;HTML/CSS;JavaScript;Perl...
# 62391       C++;HTML/CSS;JavaScript;Python;Ruby;TypeScript
# 63077              C++;HTML/CSS;Java;JavaScript;Python;SQL
# 63640    Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
# 64867    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# Name: LanguageWorkedWith, Length: 25287, dtype: object

# %%
df_2
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com

# %%
df_2.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df_2.columns = ['first_name', 'last_name', 'email_name']

# %%
df_2
# Out:
#   first_name last_name               email_name
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@gmail.com
# 2       John       Doe        JohnDoe@gmail.com

# %%
df_2.columns = [x.upper() for x in df_2.columns]

# %%
df_2
# Out:
#   FIRST_NAME LAST_NAME               EMAIL_NAME
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@gmail.com
# 2       John       Doe        JohnDoe@gmail.com

# %%
df_2.columns = df_2.columns.str.replace('_','888')

# %%
df_2
# Out:
#   FIRST888NAME LAST888NAME             EMAIL888NAME
# 0        Corey     Schafer  CoreyMSchafer@gmail.com
# 1         Jane         Doe        JaneDoe@gmail.com
# 2         John         Doe        JohnDoe@gmail.com

# %%
df_2.rename(columns={'FIRST888NAME':'first','LAST888NAME':'last','EMAIL888NAME':'email'}, inplace=True)

# %%
df_2
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com

# %%
df_2.loc[2] = ['Boris', 'theBest','YeahMan@gmail.com']

# %%
df_2
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2  Boris  theBest        YeahMan@gmail.com

# %%
df_2.loc[2, ['first','last']] = ['Patrick','LaSalope']

# %%
df_2
# Out:
#      first      last                    email
# 0    Corey   Schafer  CoreyMSchafer@gmail.com
# 1     Jane       Doe        JaneDoe@gmail.com
# 2  Patrick  LaSalope        YeahMan@gmail.com

# %%
df_2
# Out:
#      first      last                    email
# 0    Corey   Schafer  CoreyMSchafer@gmail.com
# 1     Jane       Doe        JaneDoe@gmail.com
# 2  Patrick  LaSalope        YeahMan@gmail.com

# %%
filt = (df_2.email == 'YeahMan@gmail.com')

# %%
df_2.loc[filt]['last']
# Out:
# 2    LaSalope
# Name: last, dtype: object

# %%
df_2.loc[filt, 'last'] = 'lalala'

# %%
df_2
# Out:
#      first     last                    email
# 0    Corey  Schafer  CoreyMSchafer@gmail.com
# 1     Jane      Doe        JaneDoe@gmail.com
# 2  Patrick   lalala        YeahMan@gmail.com

# %%
df_2.email = df_2.email.str.lower()

# %%
df_2
# Out:
#      first     last                    email
# 0    Corey  Schafer  coreymschafer@gmail.com
# 1     Jane      Doe        janedoe@gmail.com
# 2  Patrick   lalala        yeahman@gmail.com

# %%
df_2['first'].apply(len)
# Out:
# 0    5
# 1    4
# 2    7
# Name: first, dtype: int64

# %%
df_2.email = df_2.email.apply(lambda x:x.capitalize())

# %%
df_2
# Out:
#      first     last                    email
# 0    Corey  Schafer  Coreymschafer@gmail.com
# 1     Jane      Doe        Janedoe@gmail.com
# 2  Patrick   lalala        Yeahman@gmail.com

# %%
df_2.apply(len, axis='columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
df_2.apply(pd.Series.min)
# Out:
# first                      Corey
# last                         Doe
# email    Coreymschafer@gmail.com
# dtype: object

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
df_2
# Out:
#      first     last                    email
# 0    Corey  Schafer  Coreymschafer@gmail.com
# 1     Jane      Doe        Janedoe@gmail.com
# 2  Patrick   lalala        Yeahman@gmail.com

# %%
df_2[2, 'first'] = 'Durull'

# %%
df_2
# Out:
#      first     last                    email (2, first)
# 0    Corey  Schafer  Coreymschafer@gmail.com     Durull
# 1     Jane      Doe        Janedoe@gmail.com     Durull
# 2  Patrick   lalala        Yeahman@gmail.com     Durull

# %%
df_2.columns
# Out:
# Index(['first', 'last', 'email', (2, 'first')], dtype='object')

# %%
df_2
# Out:
#      first     last                    email (2, first)
# 0    Corey  Schafer  Coreymschafer@gmail.com     Durull
# 1     Jane      Doe        Janedoe@gmail.com     Durull
# 2  Patrick   lalala        Yeahman@gmail.com     Durull

# %%
filt44 = (df_2['email'] == 'JohnDoe@gmail.com')

# %%
df_2.loc[filt44, 'last'] = df_2.loc[filt44, 'last'].apply(lambda x:x.upper())

# %%
df_2
# Out:
#      first     last                    email (2, first)
# 0    Corey  Schafer  Coreymschafer@gmail.com     Durull
# 1     Jane      Doe        Janedoe@gmail.com     Durull
# 2  Patrick   lalala        Yeahman@gmail.com     Durull

# %%
df_2.loc[1:2, 'first'] ='Jane','John'

# %%
df_2
# Out:
#    first     last                    email (2, first)
# 0  Corey  Schafer  Coreymschafer@gmail.com     Durull
# 1   Jane      Doe        Janedoe@gmail.com     Durull
# 2   John   lalala        Yeahman@gmail.com     Durull

# %%
df_2['full_name'] = df_2['first'] + ' ' + df_2['last']

# %%
df_2.drop(columns=["first", "last"])
# Out:
#                      email (2, first)      full_name
# 0  Coreymschafer@gmail.com     Durull  Corey Schafer
# 1        Janedoe@gmail.com     Durull       Jane Doe
# 2        Yeahman@gmail.com     Durull    John lalala

# %%
df_2['full_name'].str.split(' ',expand=True)
# Out:
#        0        1
# 0  Corey  Schafer
# 1   Jane      Doe
# 2   John   lalala

# %%
df_2[['first', 'last']] = df_2['full_name'].str.split(' ',expand=True)

# %%
df_2
# Out:
#    first     last                    email (2, first)      full_name
# 0  Corey  Schafer  Coreymschafer@gmail.com     Durull  Corey Schafer
# 1   Jane      Doe        Janedoe@gmail.com     Durull       Jane Doe
# 2   John   lalala        Yeahman@gmail.com     Durull    John lalala

# %%
people = {
    'first':['TOny','Steve'],
    'last':['Strak','Rogers'],
    'email':['IronMan@gmail.com','Cap@gmail.com']
}

# %%
df_3 = pd.DataFrame(people)

# %%
df_2['full_name'] = df_2['first'] + ' ' + df_2['last']

# %%
df_2.drop(columns=['first', 'last'], inplace=True)

# %%
df_2[['first','last']] = df_2['full_name'].str.split(' ',expand=True)

# %%
df_3
# Out:
#    first    last              email
# 0   TOny   Strak  IronMan@gmail.com
# 1  Steve  Rogers      Cap@gmail.com

# %%
df_2 = df_2.append({'first':'Tonio'}, ignore_index=True)

# %%
df_2.append(df_3,ignore_index=True, sort=True)
# Out:
#                      email (2, first)      full_name  first     last
# 0  Coreymschafer@gmail.com     Durull  Corey Schafer  Corey  Schafer
# 1        Janedoe@gmail.com     Durull       Jane Doe   Jane      Doe
# 2        Yeahman@gmail.com     Durull    John lalala   John   lalala
# 3                      NaN        NaN            NaN  Tonio      NaN
# 4        IronMan@gmail.com        NaN            NaN   TOny    Strak
# 5            Cap@gmail.com        NaN            NaN  Steve   Rogers

# %%
df_3 = df_3.append(df_2,ignore_index=True,sort=True)

# %%
df_3.drop(index=5, inplace=True)

# %%
df_3
# Out:
#                      email  first     last (2, first)      full_name
# 0        IronMan@gmail.com   TOny    Strak        NaN            NaN
# 1            Cap@gmail.com  Steve   Rogers        NaN            NaN
# 2  Coreymschafer@gmail.com  Corey  Schafer     Durull  Corey Schafer
# 3        Janedoe@gmail.com   Jane      Doe     Durull       Jane Doe
# 4        Yeahman@gmail.com   John   lalala     Durull    John lalala

# %%
filt = (pd.isnull(df_3['email']))

# %%
df_3[filt]
# Out:
# Empty DataFrame
# Columns: [email, first, last, (2, first), full_name]
# Index: []

# %%
df_3.drop(df_3.index[3:7])
# Out:
#                      email  first     last (2, first)      full_name
# 0        IronMan@gmail.com   TOny    Strak        NaN            NaN
# 1            Cap@gmail.com  Steve   Rogers        NaN            NaN
# 2  Coreymschafer@gmail.com  Corey  Schafer     Durull  Corey Schafer

# %%
df_3
# Out:
#                      email  first     last (2, first)      full_name
# 0        IronMan@gmail.com   TOny    Strak        NaN            NaN
# 1            Cap@gmail.com  Steve   Rogers        NaN            NaN
# 2  Coreymschafer@gmail.com  Corey  Schafer     Durull  Corey Schafer
# 3        Janedoe@gmail.com   Jane      Doe     Durull       Jane Doe
# 4        Yeahman@gmail.com   John   lalala     Durull    John lalala

# %%
df_3.sort_values(by=['last','first'], ascending=[False, True])
# Out:
#                      email  first     last (2, first)      full_name
# 4        Yeahman@gmail.com   John   lalala     Durull    John lalala
# 0        IronMan@gmail.com   TOny    Strak        NaN            NaN
# 2  Coreymschafer@gmail.com  Corey  Schafer     Durull  Corey Schafer
# 1            Cap@gmail.com  Steve   Rogers        NaN            NaN
# 3        Janedoe@gmail.com   Jane      Doe     Durull       Jane Doe

# %%
filt = (pd.isnull(df['ConvertedComp']) | (df['ConvertedComp'] == 0))

# %%
df[~filt]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 8                              I am a developer by profession      Yes  36.0
# 10                             I am a developer by profession      Yes  22.0
# 11                             I am a developer by profession      Yes  23.0
# 12                             I am a developer by profession       No  49.0
# 13          I am not primarily a developer, but I write co...      Yes  53.0
# ...                                                       ...      ...   ...
# 65619       I am not primarily a developer, but I write co...      Yes   NaN
# 65625                          I am a developer by profession      Yes   NaN
# 65629                          I am a developer by profession      Yes  41.0
# 65630                          I am a developer by profession      Yes   NaN
# 65631                          I am a developer by profession      Yes   NaN
#
# ...

# %%
df[~filt].sort_values(by=['ConvertedComp','Country'], ascending=[True, True]).head(100)
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 13209                          I am a developer by profession       No  46.0
# 30191                          I am a developer by profession      Yes  55.0
# 56499                          I am a developer by profession      Yes  26.0
# 33583                          I am a developer by profession       No  26.0
# 32479                          I am a developer by profession      Yes  33.0
# 9209                           I am a developer by profession      Yes  22.0
# 50196                          I am a developer by profession      Yes  23.0
# 8385                           I am a developer by profession      Yes  23.0
# 15416                          I am a developer by profession      Yes  23.0
# 37225                          I am a developer by profession      Yes   NaN
# 57500                          I am a developer by profession       No  34.0
# ...

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq', 'CompTotal',
#        'ConvertedComp', 'Country', 'CurrencyDesc', 'CurrencySymbol',
#        'DatabaseDesireNextYear', 'DatabaseWorkedWith', 'DevType', 'EdLevel',
#        'Employment', 'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
country_group = df.groupby(['Country'])

# %%
country_group['LanguageWorkedWith'].apply(lambda x:x.str.contains('Python').sum()).loc['France']
# Out:
# 833

# %%
df_un = df['Country'].value_counts()

# %%
df_deux = country_group['LanguageWorkedWith'].apply(lambda x:x.str.contains('Python').sum())

# %%
df_total = pd.concat([df_un,df_deux], axis=1)

# %%
df_total.rename(columns={'Country':'Nb rEpondant pas pays','LanguageWorkedWith':'Utilisant Python'}, inplace=True)

# %%
df_total['Pourcentage'] = (df_total['Utilisant Python']/df_total['Nb rEpondant pas pays'])*100

# %%
df_total.loc['France']
# Out:
# Nb rEpondant pas pays    1898.000000
# Utilisant Python          833.000000
# Pourcentage                43.888303
# Name: France, dtype: float64
